# %% [markdown]
# ### Load Gensim Library

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.23.0)
# Requirement already satisfied: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.13.23)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2020.4.5.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.3.3)
# Requirement already satisfied: botocore<1.17.0,>=1.16.23 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.16.23)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.23->boto3->smart-open>=1.2.1->gensim) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.23->boto3->smart-open>=1.2.1->gensim) (0.15.2)

# %%
import gensim

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %% [markdown]
# ### Load Text Data
#
# Data can be downloaded from https://www.kaggle.com/c/word2vec-nlp-tutorial/data

# %%
#This is needed only if you have uploaded data to Google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd

#change file path to point to where you have stored the zip file.
df = pd.read_csv('/gdrive/My Drive/AI-ML/unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

print('Number of examples in Dataset: ', df.shape)
df.head()
# Out:
# Number of examples in Dataset:  (50000, 2)
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %%
df.loc[0, 'review']
# Out:
# '"Watching Time Chasers, it obvious that it was made by a bunch of friends. Maybe they were sitting around one day in film school and said, \\"Hey, let\'s pool our money together and make a really bad movie!\\" Or something like that. What ever they said, they still ended up making a really bad movie--dull story, bad script, lame acting, poor cinematography, bottom of the barrel stock music, etc. All corners were cut, except the one that would have prevented this film\'s release. Life\'s like that."'

# %% [markdown]
# ### Function to Clean up data

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %% [markdown]
# ### Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#           id  ...                                       clean_review
# 0   "9999_0"  ...  watching time chasers it obvious that it was m...
# 1  "45057_0"  ...  i saw this film about years ago and remember i...
# 2  "15561_0"  ...  minor spoilers br br in new york joan barnard ...
# 3   "7161_0"  ...  i went to see this film with a great deal of e...
# 4  "43971_0"  ...  yes i agree with everyone on this site this mo...
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Convert Review to a Word List

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_review']:
    documents.append(doc.split(' '))

print(len(documents))
print(documents[0])
# Out:
# 50000
# ['watching', 'time', 'chasers', 'it', 'obvious', 'that', 'it', 'was', 'made', 'by', 'a', 'bunch', 'of', 'friends', 'maybe', 'they', 'were', 'sitting', 'around', 'one', 'day', 'in', 'film', 'school', 'and', 'said', 'hey', 'let', 's', 'pool', 'our', 'money', 'together', 'and', 'make', 'a', 'really', 'bad', 'movie', 'or', 'something', 'like', 'that', 'what', 'ever', 'they', 'said', 'they', 'still', 'ended', 'up', 'making', 'a', 'really', 'bad', 'movie', 'dull', 'story', 'bad', 'script', 'lame', 'acting', 'poor', 'cinematography', 'bottom', 'of', 'the', 'barrel', 'stock', 'music', 'etc', 'all', 'corners', 'were', 'cut', 'except', 'the', 'one', 'that', 'would', 'have', 'prevented', 'this', 'film', 's', 'release', 'life', 's', 'like', 'that']

# %%
#documents[0]

# %% [markdown]
# ### Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPU Cores
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2020-06-13 06:12:11,709 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2020-06-13 06:12:11,712 : INFO : collecting all words and their counts
# 2020-06-13 06:12:11,713 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-06-13 06:12:12,229 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2020-06-13 06:12:12,720 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2020-06-13 06:12:13,230 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2020-06-13 06:12:13,734 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2020-06-13 06:12:14,246 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2020-06-13 06:12:14,247 : INFO : Loading a fresh vocabulary
# 2020-06-13 06:12:14,672 : INFO : effective_min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2020-06-13 06:12:14,673 : INFO : effective_min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2020-06-13 06:12:14,770 : INFO : deleting the raw counts dictionary of 100479 items
# 2020-06-13 06:12:14,775 : INFO : sample=0.001 downsamples 49 most-common words
: INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-06-13 06:15:24,914 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-06-13 06:15:24,919 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-06-13 06:15:24,927 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-06-13 06:15:24,928 : INFO : EPOCH - 10 : training on 12084660 raw words (8816112 effective words) took 18.5s, 475306 effective words/s
# 2020-06-13 06:15:24,929 : INFO : training on a 120846600 raw words (88169467 effective words) took 184.5s, 477918 effective words/s

# %%
#documents[0]

# %% [markdown]
# # Exploring the model

# %% [markdown]
# ### How many words in the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# (28322, 50)

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x7f1e268a70f0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f1e268a7160>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e390>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e438>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e470>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e4e0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e518>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e550>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e588>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e5c0>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e5f8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e630>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e668>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e6a0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e6d8>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e710>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e748>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e780>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e7b8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e7f0>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e828>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e860>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e898>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e8d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e908>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e940>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e978>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e9b0>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64e9e8>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ea20>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ea58>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ea90>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eac8>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eb00>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eb38>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eb70>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eba8>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ebe0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ec18>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ec50>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ec88>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ecc0>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ecf8>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ed30>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ed68>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eda0>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64edd8>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ee10>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ee48>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ee80>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eeb8>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64eef0>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ef28>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ef60>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64ef98>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f1ddc64efd0>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d048>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d080>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d0b8>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d0f0>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d128>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d160>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d198>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d1d0>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d208>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d240>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d278>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d2b0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d2e8>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d320>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d358>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d390>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d3c8>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d400>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d438>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d470>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d4a8>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d4e0>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d518>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d550>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d588>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d5c0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d5f8>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d630>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d668>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d6a0>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d6d8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d710>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d748>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d780>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d7b8>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d7f0>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d828>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d860>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d898>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d8d0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d908>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d940>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d978>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d9b0>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66d9e8>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66da20>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66da58>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66da90>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dac8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66db00>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66db38>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66db70>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dba8>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dbe0>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dc18>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dc50>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dc88>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dcc0>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dcf8>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dd30>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dd68>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dda0>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66ddd8>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66de10>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66de48>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66de80>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66deb8>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66def0>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66df28>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66df60>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66df98>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66dfd0>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f048>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f080>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f0b8>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f0f0>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f128>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f160>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f198>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f1d0>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f208>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f240>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f278>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f2b0>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f2e8>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f320>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f358>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f390>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f3c8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f400>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f438>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f470>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f4a8>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f4e0>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f518>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f550>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f588>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f5c0>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f5f8>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f630>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f668>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f6a0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f6d8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f710>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f748>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f780>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f7b8>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f7f0>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f828>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f860>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f898>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f8d0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f908>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f940>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f978>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f9b0>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66f9e8>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fa20>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fa58>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fa90>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fac8>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fb00>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fb38>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fb70>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fba8>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fbe0>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fc18>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fc50>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fc88>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fcc0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fcf8>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fd30>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fd68>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fda0>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fdd8>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fe10>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fe48>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fe80>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66feb8>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66fef0>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66ff28>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66ff60>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66ff98>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f1ddc66ffd0>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672048>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672080>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6720b8>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6720f0>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672128>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672160>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672198>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6721d0>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672208>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672240>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672278>,
#  'credits': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6722b0>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6722e8>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672320>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672358>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672390>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6723c8>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672400>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672438>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672470>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6724a8>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6724e0>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672518>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672550>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672588>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6725c0>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6725f8>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672630>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672668>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6726a0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6726d8>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672710>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672748>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672780>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6727b8>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6727f0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672828>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672860>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672898>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6728d0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672908>,
#  'navigate': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672940>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672978>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6729b0>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6729e8>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672a20>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672a58>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672a90>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672ac8>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672b00>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672b38>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672b70>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672ba8>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672be0>,
#  'mist': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672c18>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672c50>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672c88>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672cc0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672cf8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672d30>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672d68>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672da0>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672dd8>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672e10>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672e48>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672e80>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672eb8>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672ef0>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672f28>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672f60>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672f98>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f1ddc672fd0>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676048>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676080>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6760b8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6760f0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676128>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676160>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676198>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6761d0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676208>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676240>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676278>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6762b0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6762e8>,
#  'balcony': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676320>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676358>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676390>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6763c8>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676400>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676438>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676470>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6764a8>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6764e0>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676518>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676550>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676588>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6765c0>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6765f8>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676630>,
#  'reporters': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676668>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6766a0>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6766d8>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676710>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676748>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676780>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6767b8>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6767f0>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676828>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676860>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676898>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6768d0>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676908>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676940>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676978>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6769b0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6769e8>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676a20>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676a58>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676a90>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676ac8>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676b00>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676b38>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676b70>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676ba8>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676be0>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676c18>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676c50>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676c88>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676cc0>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676cf8>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676d30>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676d68>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676da0>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676dd8>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676e10>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676e48>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676e80>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676eb8>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676ef0>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676f28>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676f60>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676f98>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x7f1ddc676fd0>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678048>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678080>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6780b8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6780f0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678128>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678160>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678198>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6781d0>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678208>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678240>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678278>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6782b0>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6782e8>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678320>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678358>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678390>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6783c8>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678400>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678438>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678470>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6784a8>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6784e0>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678518>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678550>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678588>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6785c0>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6785f8>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678630>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678668>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6786a0>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6786d8>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678710>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678748>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678780>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6787b8>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6787f0>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678828>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678860>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678898>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6788d0>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678908>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678940>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678978>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6789b0>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6789e8>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678a20>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678a58>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678a90>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678ac8>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678b00>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678b38>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678b70>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678ba8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678be0>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678c18>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678c50>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678c88>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678cc0>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678cf8>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678d30>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678d68>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678da0>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678dd8>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678e10>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678e48>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678e80>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678eb8>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678ef0>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678f28>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678f60>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678f98>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f1ddc678fd0>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c048>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c080>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c0b8>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c0f0>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c128>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c160>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c198>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c1d0>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c208>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c240>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c278>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c2b0>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c2e8>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c320>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c358>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c390>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c3c8>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c400>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c438>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c470>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c4a8>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c4e0>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c518>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c550>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c588>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c5c0>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c5f8>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c630>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c668>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c6a0>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c6d8>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c710>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c748>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c780>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c7b8>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c7f0>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c828>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c860>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c898>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c8d0>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c908>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c940>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c978>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c9b0>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67c9e8>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ca20>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ca58>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ca90>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cac8>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cb00>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cb38>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cb70>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cba8>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cbe0>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cc18>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cc50>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cc88>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ccc0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ccf8>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cd30>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cd68>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cda0>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cdd8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ce10>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ce48>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ce80>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67ceb8>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cef0>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cf28>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cf60>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cf98>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f1ddc67cfd0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601048>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601080>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6010b8>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6010f0>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601128>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601160>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601198>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6011d0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601208>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601240>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601278>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6012b0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6012e8>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601320>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601358>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601390>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6013c8>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601400>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601438>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601470>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6014a8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6014e0>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601518>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601550>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601588>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6015c0>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6015f8>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601630>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601668>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6016a0>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6016d8>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601710>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601748>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601780>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6017b8>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6017f0>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601828>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601860>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601898>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6018d0>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601908>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601940>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601978>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6019b0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6019e8>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601a20>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601a58>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601a90>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601ac8>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601b00>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601b38>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601b70>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601ba8>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601be0>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601c18>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601c50>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601c88>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601cc0>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601cf8>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601d30>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601d68>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601da0>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601dd8>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601e10>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601e48>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601e80>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601eb8>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601ef0>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601f28>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601f60>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601f98>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f1ddc601fd0>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604048>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604080>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6040b8>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6040f0>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604128>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604160>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604198>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6041d0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604208>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604240>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604278>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6042b0>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6042e8>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604320>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604358>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604390>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6043c8>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604400>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604438>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604470>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6044a8>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6044e0>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604518>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604550>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604588>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6045c0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6045f8>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604630>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604668>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6046a0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6046d8>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604710>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604748>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604780>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6047b8>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6047f0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604828>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604860>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604898>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6048d0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604908>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604940>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604978>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6049b0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6049e8>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604a20>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604a58>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604a90>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604ac8>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604b00>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604b38>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604b70>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604ba8>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604be0>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604c18>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604c50>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604c88>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604cc0>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604cf8>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604d30>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604d68>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604da0>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604dd8>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604e10>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604e48>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604e80>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604eb8>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604ef0>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604f28>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604f60>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604f98>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7f1ddc604fd0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607048>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607080>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6070b8>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6070f0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607128>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607160>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607198>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6071d0>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607208>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607240>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607278>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6072b0>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6072e8>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607320>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607358>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607390>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6073c8>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607400>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607438>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607470>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6074a8>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6074e0>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607518>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607550>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607588>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6075c0>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6075f8>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607630>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607668>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6076a0>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6076d8>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607710>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607748>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607780>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6077b8>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6077f0>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607828>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607860>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607898>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6078d0>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607908>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607940>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607978>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6079b0>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6079e8>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607a20>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607a58>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607a90>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607ac8>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607b00>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607b38>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607b70>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607ba8>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607be0>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607c18>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607c50>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607c88>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607cc0>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607cf8>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607d30>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607d68>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607da0>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607dd8>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607e10>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607e48>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607e80>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607eb8>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607ef0>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607f28>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607f60>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607f98>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7f1ddc607fd0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a048>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a080>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a0b8>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a0f0>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a128>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a160>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a198>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a1d0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a208>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a240>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a278>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a2b0>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a2e8>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a320>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a358>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a390>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a3c8>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a400>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a438>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a470>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a4a8>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a4e0>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a518>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a550>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a588>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a5c0>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a5f8>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a630>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a668>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a6a0>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a6d8>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a710>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a748>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a780>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a7b8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60a7f0>,
# ...
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60aba8>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60abe0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ac18>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ac50>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ac88>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60acc0>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60acf8>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ad30>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ad68>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ada0>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60add8>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ae10>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ae48>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ae80>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60aeb8>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60aef0>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60af28>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60af60>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60af98>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60afd0>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f048>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f080>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f0b8>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f0f0>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f128>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f160>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f198>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f1d0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f208>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f240>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f278>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f2b0>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f2e8>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f320>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f358>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f390>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f3c8>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f400>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f438>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f470>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f4a8>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f4e0>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f518>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f550>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f588>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f5c0>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f5f8>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f630>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f668>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f6a0>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f6d8>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f710>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f748>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f780>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f7b8>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f7f0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f828>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f860>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f898>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f8d0>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f908>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f940>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f978>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f9b0>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60f9e8>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fa20>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fa58>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fa90>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fac8>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fb00>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fb38>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fb70>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fba8>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fbe0>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fc18>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fc50>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fc88>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fcc0>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fcf8>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fd30>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fd68>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fda0>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fdd8>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fe10>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fe48>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fe80>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60feb8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60fef0>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ff28>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ff60>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ff98>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f1ddc60ffd0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611048>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611080>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6110b8>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6110f0>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611128>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611160>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611198>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6111d0>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611208>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611240>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611278>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6112b0>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6112e8>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611320>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611358>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f1ddc69efd0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611390>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6113c8>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611400>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611438>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611470>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6114a8>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6114e0>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611518>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611550>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611588>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6115c0>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6115f8>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611630>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611668>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6116a0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6116d8>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611710>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611748>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611780>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6117b8>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6117f0>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611828>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611860>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611898>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6118d0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611908>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611940>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611978>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6119b0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6119e8>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611a20>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611a58>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611a90>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611ac8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611b00>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611b38>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611b70>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611ba8>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611be0>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611c18>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611c50>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611c88>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611cc0>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611cf8>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611d30>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611d68>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611da0>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611dd8>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611e10>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611e48>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611e80>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611eb8>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611ef0>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611f28>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611f60>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611f98>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7f1ddc611fd0>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615048>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615080>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6150b8>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6150f0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615128>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615160>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615198>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6151d0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615208>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615240>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615278>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6152b0>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6152e8>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615320>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615358>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615390>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6153c8>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615400>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615438>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615470>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6154a8>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6154e0>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615518>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615550>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615588>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6155c0>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6155f8>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615630>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615668>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6156a0>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6156d8>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615710>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615748>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615780>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6157b8>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6157f0>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615828>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615860>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615898>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6158d0>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615908>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615940>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615978>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6159b0>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f1ddc6159e8>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615a20>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615a58>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615a90>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615ac8>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615b00>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615b38>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615b70>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615ba8>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615be0>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615c18>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615c50>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615c88>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615cc0>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615cf8>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615d30>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615d68>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615da0>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615dd8>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615e10>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615e48>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615e80>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615eb8>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615ef0>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615f28>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615f60>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615f98>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f1ddc615fd0>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a048>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a080>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a0b8>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a0f0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a128>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a160>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x7f1ddc61a198>,
#  ...}

# %% [markdown]
# ### Get an embedding for a word

# %%
model.wv['flower']
# Out:
# array([-0.14810558, -0.71751475,  0.60191846, -0.18540882,  0.7577236 ,
#        -0.2769248 ,  0.31264266,  0.7332015 ,  0.9792783 ,  1.4231142 ,
#         0.7711015 , -0.62922776,  1.0930786 , -0.5608674 , -0.70426786,
#         1.1644068 , -0.6798673 , -0.00758035, -0.5645974 , -0.17416641,
#        -0.19669205,  1.0966979 ,  0.861114  ,  0.2700012 ,  0.57455045,
#        -0.31086162, -1.2841402 , -0.29588827, -0.21599896, -0.39557472,
#        -0.04301611, -0.111603  ,  0.9452557 , -0.78471106,  0.09595187,
#        -1.8731594 , -0.06825525,  0.8234651 ,  0.37180844, -0.30128375,
#        -0.5152668 , -0.43481266, -0.56009793,  0.5890917 , -0.993304  ,
#        -0.20824367,  1.1495295 , -0.10978289, -0.1285663 , -0.55448395],
#       dtype=float32)

# %% [markdown]
# ### Finding Words which have similar meaning

# %%
model.wv.most_similar('great')
# Out:
# 2020-06-13 06:19:22,321 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('fantastic', 0.887427568435669),
#  ('wonderful', 0.8820511698722839),
#  ('terrific', 0.8731141686439514),
#  ('fine', 0.8548595309257507),
#  ('good', 0.8238403797149658),
#  ('brilliant', 0.804119884967804),
#  ('superb', 0.7887728214263916),
#  ('perfect', 0.768755316734314),
#  ('nice', 0.7584500908851624),
#  ('remarkable', 0.7455489635467529)]

# %% [markdown]
# ### Find the word which is not like others

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'kitchen'

# %% [markdown]
# ### Saving the model

# %%
model.save('word2vec-movie-50')

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-movie-50')

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('soldier', 0.572564423084259),
#  ('batman', 0.5400917530059814),
#  ('joker', 0.5323717594146729),
#  ('buio', 0.5322198271751404),
#  ('prophecy', 0.5291051268577576),
#  ('spielberg', 0.5290843844413757),
#  ('scientist', 0.5277968645095825),
#  ('boy', 0.5190491676330566),
#  ('seagal', 0.5157371163368225),
#  ('marine', 0.4934084713459015)]

# %%
model.wv['king'] + model.wv['man'] - model.wv['queen']
